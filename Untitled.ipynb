# %%
import pandas as pd

# %%
df = pd.read_excel('Soyabean/Soyabean 2019.xls', engine='openpyxl')
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_excel('Soyabean/Soyabean 2019.xls', engine='openpyxl')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
# ...

# %%
df
# Out:
#                      commodity_name    state    district           market  \
# 0                             Ajwan  Gujarat      Amreli           Amreli
# 1                             Ajwan  Gujarat  Banaskanth          Dhanera
# 2                             Ajwan  Gujarat    Jamnagar         Jamnagar
# 3                             Ajwan  Gujarat     Mehsana             Kadi
# 4                             Ajwan  Gujarat     Mehsana            Unjha
# ...                             ...      ...         ...              ...
# 836972  Arhar (Tur/Red Gram)(Whole)  Gujarat     Bharuch  Jambusar(Kaavi)
# 836973  Arhar (Tur/Red Gram)(Whole)  Gujarat      Rajkot           Jasdan
# 836974  Arhar (Tur/Red Gram)(Whole)  Gujarat      Rajkot           Rajkot
# 836975  Arhar (Tur/Red Gram)(Whole)  Gujarat    Junagarh        Visavadar
# 836976  Arhar (Tur/Red Gram)(Whole)   Kerala    Kasargod      Neeleswaram
#
#         min_price  max_price  modal_price         date
# ...

# %%
df.shape
# Out:
# (836977, 8)

# %%
sort_df = df.sort_values(by = 'state')
sort_df
# Out:
#        commodity_name                state    district         market  \
# 834337            its                 1.50        3000           5000
# 53272       Drumstick  Andaman and Nicobar     Nicobar    Car Nicobar
# 57837         Brinjal  Andaman and Nicobar     Nicobar    Car Nicobar
# 59576          Potato  Andaman and Nicobar     Nicobar    Car Nicobar
# 61330           Onion  Andaman and Nicobar     Nicobar    Car Nicobar
# ...               ...                  ...         ...            ...
# 637144         Potato          West Bengal     Burdwan        Asansol
# 36183         Brinjal          West Bengal  Jalpaiguri       Dhupguri
# 637147         Potato          West Bengal     Birbhum         Bolpur
# 364738          Onion          West Bengal       Malda  English Bazar
# 98547          Tomato          West Bengal     Burdwan          Kalna
#
#         min_price  max_price  modal_price        date
# 834337        NaN        NaN          NaN         NaN
# ...

# %%
df = df[df['state'] == 'Madhya Pradesh']
df
# Out:
#                      commodity_name           state     district  \
# 5                             Ajwan  Madhya Pradesh      Neemuch
# 11                    Alasande+Gram  Madhya Pradesh        Panna
# 52                  Amla(Nelli+Kai)  Madhya Pradesh      Neemuch
# 104                           Apple  Madhya Pradesh        Harda
# 219              Arhar+Dal(Tur+Dal)  Madhya Pradesh        Sagar
# ...                             ...             ...          ...
# 836883  Arhar (Tur/Red Gram)(Whole)  Madhya Pradesh    Alirajpur
# 836884  Arhar (Tur/Red Gram)(Whole)  Madhya Pradesh  Narsinghpur
# 836885  Arhar (Tur/Red Gram)(Whole)  Madhya Pradesh       Raisen
# 836886  Arhar (Tur/Red Gram)(Whole)  Madhya Pradesh       Ratlam
# 836910  Arhar (Tur/Red Gram)(Whole)  Madhya Pradesh   Chhindwara
#
#               market  min_price  max_price  modal_price         date
# 5            Neemuch       80.0      132.0         95.0   2019-05-22
# ...

# %%
sort_df = df.sort_values(by = 'commodity_name')

# %%
sort_df
# Out:
#        commodity_name           state  district     market  min_price  \
# 5               Ajwan  Madhya Pradesh   Neemuch    Neemuch      80.00
# 364603          Ajwan  Madhya Pradesh   Neemuch    Neemuch      45.00
# 370842          Ajwan  Madhya Pradesh   Neemuch    Neemuch      84.01
# 376964          Ajwan  Madhya Pradesh   Neemuch    Neemuch      86.01
# 377732          Ajwan  Madhya Pradesh   Neemuch    Neemuch      66.00
# ...               ...             ...       ...        ...        ...
# 403562     White+Peas  Madhya Pradesh  Jabalpur   Jabalpur      15.00
# 194804     White+Peas  Madhya Pradesh    Raisen   Udaipura      38.00
# 589907   Yam+(Ratalu)  Madhya Pradesh      Dhar  Dhar(F&V)      10.00
# 578352   Yam+(Ratalu)  Madhya Pradesh      Dhar  Dhar(F&V)      12.00
# 604831   Yam+(Ratalu)  Madhya Pradesh      Dhar  Dhar(F&V)      20.00
#
#         max_price  modal_price        date
# 5          132.00         95.0  2019-05-22
# ...

# %%
df.to_csv('madhya_pradesh_data.csv', index=False)

# %%
type(df['date'])
# Out:
# pandas.core.series.Series
